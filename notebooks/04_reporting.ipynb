# %% [markdown]
# # PD-and-Scorecard-Cashflow-Lending - Reporting
#
# Standard notebook placeholder for the rebuilt PD-and-Scorecard-Cashflow-Lending workflow.

# %%
from src.codex_run_pipeline import run_pipeline
result = run_pipeline(persist=True)
result["validation"].head()
